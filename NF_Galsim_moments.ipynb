# %% [markdown]
# ## Dataset import

# %%
import tensorflow as tf
import os
import jax
import numpy as np
import sys
import wandb
import jax.numpy as jnp
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from jax.lib import xla_bridge
from galsim_jax.datasets import cosmos
from flax import linen as nn  # Linen API

from galsim_jax.dif_models import AutoencoderKLModule
from galsim_jax.utils import (
    load_checkpoint_wandb,
    plot_examples,
    get_git_commit_version,
)
from galsim_jax.convolution import convolve_kpsf
from galsim_jax.nf_models import (
    encode,
    decode,
    NeuralSplineFlowLogProb,
    NeuralSplineFlowSampler,
)

# Set the CUDA_VISIBLE_DEVICES environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = str('2')
os.environ["XLA_FLAGS"] = "--xla_gpu_cuda_data_dir=/usr/local/cuda-12.1"
os.environ["XLA_FLAGS"] = "--xla_gpu_force_compilation_parallelism=1"

# Checking for GPU access
print("Device: {}".format(xla_bridge.get_backend().platform))

# Checking the GPU available
gpus = jax.devices("gpu")
print("Number of avaliable devices : {}".format(len(gpus)))

# Ensure TF does not see GPU and grab all GPU memory.
tf.config.set_visible_devices([], device_type="GPU")
# Out:
# 2023-09-27 15:41:01.136950: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-27 15:41:01.191931: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 15:41:02.028916: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Device: gpu
# Number of avaliable devices : 1

# %%
# Loading the dataset and transforming it to NumPy Arrays
train_dset, info = tfds.load(name='Cosmos/25.2', with_info=True, split="train")

# What's in our dataset:
# info

def input_fn(mode="train", batch_size=32):
    """
    mode: 'train' or 'test'
    """

    def preprocess_image(data):
        # Reshape 'psf' and 'image' to (128, 128, 1)
        data["kpsf_real"] = tf.expand_dims(data["kpsf_real"], axis=-1)
        data["kpsf_imag"] = tf.expand_dims(data["kpsf_imag"], axis=-1)
        data["image"] = tf.expand_dims(data["image"], axis=-1)
        return data

    if mode == "train":
        dataset = tfds.load('Cosmos/25.2', split="train")
        dataset = dataset.repeat()
        dataset = dataset.shuffle(10000)
    else:
        dataset = tfds.load('Cosmos/25.2', split="test")

    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.map(preprocess_image)  # Apply data preprocessing
    dataset = dataset.prefetch(
        -1
    )  # fetch next batches while training current one (-1 for autotune)
    return dataset

# Dataset as a numpy iterator
dset = input_fn().as_numpy_iterator()
# Out:
# WARNING:absl:You use TensorFlow DType <dtype: 'float32'> in tfds.features This will soon be deprecated in favor of NumPy DTypes. In the meantime it was converted to float32.

# %% [markdown]
# ## Initializing the autoencoder

# %%
# Generating a random key for JAX
rng, rng_2 = jax.random.PRNGKey(0), jax.random.PRNGKey(1)
# Size of the input to initialize the encoder parameters
batch_autoenc = jnp.ones((1, 128, 128, 1))

latent_dim = 128
act_fn = nn.gelu

# Initializing the AutoEncoder
Autoencoder = AutoencoderKLModule(
    ch_mult=(1, 2, 4, 8, 16),
    num_res_blocks=3,
    double_z=True,
    z_channels=1,
    resolution=latent_dim,
    in_channels=1,
    out_ch=1,
    ch=1,
    embed_dim=1,
    act_fn=act_fn,
)

params_auto = Autoencoder.init(rng, x=batch_autoenc, seed=rng_2)
# Out:
# x : (1, 128, 128, 1)
# Conv_in : (1, 128, 128, 1)
# Down : (1, 8, 8, 16)
# Mid : (1, 8, 8, 16)
# Conv_out : (1, 8, 8, 2)
# Moments shape : (1, 8, 8, 2)
# Posterior : tfp.distributions.MultivariateNormalDiag("MultivariateNormalDiag", batch_shape=[1, 8, 8], event_shape=[1], dtype=float32)
# Working with z of shape (1, 1, 8, 8) = 64 dimensions.

# %%
# Login to wandb
wandb.login()

# Initializing a Weights & Biases Run
wandb.init(
    project='NF-results',
    name='exp-6',
)

# Setting the configs of our experiment using `wandb.config`.
# This way, Weights & Biases automatically syncs the configs of
# our experiment which could be used to reproduce the results of an experiment.
config = wandb.config
config.commit_version = get_git_commit_version()
# Out:
# wandb: Currently logged in as: jonnyytorres. Use `wandb login --relogin` to force relogin
# wandb version 0.15.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/local/home/jt275011/Tutorials/wandb/run-20230927_154134-tqspded4</code>
# Syncing run <strong><a href='https://wandb.ai/jonnyytorres/NF-results/runs/tqspded4' target="_blank">exp-6</a></strong> to <a href='https://wandb.ai/jonnyytorres/NF-results' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jonnyytorres/NF-results' target="_blank">https://wandb.ai/jonnyytorres/NF-results</a>
#  View run at <a href='https://wandb.ai/jonnyytorres/NF-results/runs/tqspded4' target="_blank">https://wandb.ai/jonnyytorres/NF-results/runs/tqspded4</a>

# %% [markdown]
# ## Downloading checkpoint from Wandb

# %%
api = wandb.Api()

# %%
run = api.run("jonnyytorres/VAE-SD-NewELBO/ypziyp89")

artifact = api.artifact('jonnyytorres/VAE-SD-NewELBO/ypziyp89-checkpoint:best', type='model')
artifact_dir = artifact.download()

# Loading checkpoint for the best step
params_auto = load_checkpoint_wandb(run.id, "checkpoint.msgpack", params_auto)
# Out:
# wandb:   1 of 1 files downloaded.

# %% [markdown]
# ## Defining the encoder from the AutoEncoder module

# %%
enc = encode(ch_mult=(1, 2, 4, 8, 16),
    num_res_blocks=3,
    double_z=True,
    z_channels=1,
    resolution=latent_dim,
    in_channels=1,
    out_ch=1,
    ch=1,
    embed_dim=1,
    act_fn=act_fn)

# %%
# Iterating over the TFDS dataset
dataset_eval = input_fn("train")
test_iterator = dataset_eval.as_numpy_iterator()
batch = next(test_iterator)

# Taking a batch of images
x = batch["image"]

# %%
posterior = enc.apply(params_auto, x)
# Out:
# x : (32, 128, 128, 1)
# Conv_in : (32, 128, 128, 1)
# Down : (32, 8, 8, 16)
# Mid : (32, 8, 8, 16)
# Conv_out : (32, 8, 8, 2)
# Moments shape : (32, 8, 8, 2)
# Posterior : tfp.distributions.MultivariateNormalDiag("MultivariateNormalDiag", batch_shape=[32, 8, 8], event_shape=[1], dtype=float32)

# %%
rng, rng_2 = jax.random.split(rng_2)

z = posterior.sample(seed=rng)

# Converting array into float32
z_ = np.float32(z)

# %%
z_.shape
# Out:
# (32, 8, 8, 1)

# %%
@jax.jit
def encode(params, x):
  return enc.apply(params, x)

# %%
for i in range(624):
    # batch of dataset
    batch = next(test_iterator)

    # Taking a batch of images
    x = batch["image"]

    # Estimating the posterior by using the encoder
    posterior = encode(params_auto, x)

    # Generating a new pseudo-random key
    rng, rng_2 = jax.random.split(rng_2)

    # Sampling over the posterior
    z2 = posterior.sample(seed=rng)
    
    # Converting array into float32
    z2 = np.float32(z2)

    # Appending to existing array
    z_ = np.append(z_, z2, axis=0)
    
# Veryfing the shape of the final array
z_.shape
# Out:
# x : (32, 128, 128, 1)
# Conv_in : (32, 128, 128, 1)
# Down : (32, 8, 8, 16)
# Mid : (32, 8, 8, 16)
# Conv_out : (32, 8, 8, 2)
# Moments shape : (32, 8, 8, 2)
# Posterior : tfp.distributions.MultivariateNormalDiag("MultivariateNormalDiag", batch_shape=[32, 8, 8], event_shape=[1], dtype=float32)
# (20000, 8, 8, 1)

# %%
z_ = z_.reshape(20000,64)

# %%
z_.shape
# Out:
# (20000, 64)

# %%
plt.hist2d(z_[:,0], z_[:,1], 64);

# %%
import matplotlib.pyplot as plt

# Plotting the original, predicted and their differences for 8 examples
num_rows, num_cols = 4, 8

plt.figure(figsize=(14.5, 8))

fig, axes = plt.subplots(num_rows, num_cols, figsize=(14.5, 8))

for ax, z_img in zip(axes.flatten(), z):
    ax.imshow(z_img)
    ax.axis("off")

# Add a title to the figure
fig.suptitle("Samplings over Latent space", fontsize=12, y=0.99)

# Adjust the layout of the subplots
fig.tight_layout()

cb_ax = fig.add_axes([1.005,.03,.015,.90])
fig.colorbar(ax.imshow(z_img),label="Pixel Value", orientation="vertical", cax=cb_ax) #,ax=axes.ravel().tolist())

# plt.savefig('Original_FR_galaxies_2.png')
# plt.close(fig)

# %%
# Histogram of z values
plt.hist(z.flatten(),100, label='z value');
plt.legend();

# %%
# Taking a bunch of images 
batch = next(dset)
x = batch['image']

# Plotting the original, predicted and their differences for 8 examples
num_rows, num_cols = 4, 8

plt.figure(figsize=(14.5, 8))

fig, axes = plt.subplots(num_rows, num_cols, figsize=(14.5, 8))

for ax, z_img in zip(axes.flatten(), x):
    ax.imshow(z_img)
    ax.axis("off")

# Add a title to the figure
fig.suptitle("Galaxies examples", fontsize=12, y=0.99)

# Adjust the layout of the subplots
fig.tight_layout()

cb_ax = fig.add_axes([1.005,.03,.015,.90])
fig.colorbar(ax.imshow(z_img),label="Pixel Value", orientation="vertical", cax=cb_ax) #,ax=axes.ravel().tolist())

# plt.savefig('Original_FR_galaxies_2.png')
# plt.close(fig)

# %% [markdown]
# ## Testing the decoder

# %%
dec = decode(ch_mult=(1, 2, 4, 8, 16),
    num_res_blocks=3,
    double_z=True,
    z_channels=1,
    resolution=latent_dim,
    in_channels=1,
    out_ch=1,
    ch=1,
    embed_dim=1,
    act_fn=act_fn)

# %%
x_galaxie = dec.apply(params_auto, z)

kpsf_real = batch["kpsf_real"]
kpsf_imag = batch["kpsf_imag"]
kpsf = kpsf_real + 1j * kpsf_imag
std = batch["noise_std"].reshape((-1, 1, 1, 1))

# Converting array into float32
std = np.float32(std)

# Generating a random key for JAX
rng, rng_2 = jax.random.PRNGKey(0), jax.random.PRNGKey(1)

rng, rng_1 = jax.random.split(rng)
# X estimated distribution

x_convolve_ = jax.vmap(convolve_kpsf)(x_galaxie[..., 0], kpsf[..., 0])

x_convolve_ = tf.expand_dims(x_convolve_, axis=-1)
# Out:
# Working with z of shape (1, 1, 8, 8) = 64 dimensions.

# %%
x_galaxie.shape
# Out:
# (32, 128, 128, 1)

# %%
# Plotting the original, predicted and their differences for 8 examples
num_rows, num_cols = 4, 8

plt.figure(figsize=(14.5, 8))

fig, axes = plt.subplots(num_rows, num_cols, figsize=(14.5, 8))

for ax, z_img in zip(axes.flatten(), x_convolve_):
    ax.imshow(z_img)
    ax.axis("off")

# Add a title to the figure
fig.suptitle("Decoded galaxies", fontsize=12, y=0.99)

# Adjust the layout of the subplots
fig.tight_layout()

cb_ax = fig.add_axes([1.005,.03,.015,.90])
fig.colorbar(ax.imshow(z_img),label="Pixel Value", orientation="vertical", cax=cb_ax) #,ax=axes.ravel().tolist())

# %% [markdown]
# ## Normalizing Flow

# %%
# Calling the NF model
model = NeuralSplineFlowLogProb()

# Random seed for initializing network and sampling training data
seed = jax.random.PRNGKey(42)

# Initializes the weights of the model
params_nf = model.init(seed, jnp.zeros((1, 64)))

# Calling the NF Sampler
sampler = NeuralSplineFlowSampler()

# Obtaining the id for the best NF experiment
id_run = "aq9fnxzc"

# Downloading best checkpoint params
run = api.run("jonnyytorres/NF_experiments/{}".format(id_run))
artifact = api.artifact(
    "jonnyytorres/NF_experiments/{}-checkpoint:best".format(id_run), type="model"
)
artifact_dir = artifact.download()

# Loading checkpoint for the best step
params_nf = load_checkpoint_wandb(run.id, "checkpoint.msgpack", params_nf)
# Out:
# /local/home/jt275011/.local/lib/python3.8/site-packages/tensorflow_probability/python/internal/backend/jax/ops.py:285: UserWarning: Explicitly requested dtype int64 requested in astype is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return arr.astype(dtype)
# wandb:   1 of 1 files downloaded.

# %% [markdown]
# ## Testing the sampler

# %%
sampler = NeuralSplineFlowSampler()

# %%
# Downloading best checkpoint params
run = api.run("jonnyytorres/NF_experiments/{}".format(id_run))
artifact = api.artifact('jonnyytorres/NF_experiments/{}-checkpoint:best'.format(id_run), type='model') 
artifact_dir = artifact.download()

# Loading checkpoint for the best step
params_nf = load_checkpoint_wandb(run.id, "checkpoint.msgpack", params_nf)
# Out:
# wandb:   1 of 1 files downloaded.

# %%
samps = sampler.apply(params_nf, jax.random.PRNGKey(1), 20000)

# %%
samps.shape
# Out:
# (20000, 64)

# %%
samps.mean()
# Out:
# Array(0.84193903, dtype=float32)

# %%
plt.hist2d(samps[:,0], samps[:,1],64);

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_2_histograms(data1_x, data1_y, data2_x, data2_y):

    # Plot the histograms as heatmaps
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.hist2d(data1_x, data1_y, bins=64)
    plt.title('Distribution of samples of original z')
    
    plt.subplot(1, 2, 2)
    plt.hist2d(data2_x, data2_y, bins=64)
    plt.title('Distribution of samples of estimated z')
    
    # plt.colorbar()
    plt.show()

# %%
plot_2_histograms(samps[:,0], samps[:,1], z_[:,0], z_[:,1])

# %%
samps = sampler.apply(params_nf, jax.random.PRNGKey(1), 32)

# %%
# Resahping to original bottleneck size
samps_r = samps.reshape(-1,8,8,1)

# %%
samps_r.shape
# Out:
# (32, 8, 8, 1)

# %% [markdown]
# ## Using the decoder to reconstruct the galaxy images

# %%
q_nf = dec.apply(params_auto, samps_r)
# Out:
# Working with z of shape (1, 1, 8, 8) = 64 dimensions.

# %%
# Example of a sampled galaxy before the convolution with the PSF 
plt.imshow(q_nf[0,...,0])

# %%
q_nf[...,-1].shape
# Out:
# (32, 128, 128)

# %%
kpsf_real = batch["kpsf_real"]
kpsf_imag = batch["kpsf_imag"]
kpsf = kpsf_real + 1j * kpsf_imag
std = batch["noise_std"].reshape((-1, 1, 1, 1))

# Converting array into float32
std = np.float32(std)

# Generating a random key for JAX
rng, rng_2 = jax.random.PRNGKey(0), jax.random.PRNGKey(1)

rng, rng_1 = jax.random.split(rng)
# X estimated distribution

x_convolve = jax.vmap(convolve_kpsf)(q_nf[..., 0], kpsf[..., 0])

x_convolve = tf.expand_dims(x_convolve, axis=-1)

# z3 = x_convolve

# p3 = tfd.MultivariateNormalDiag(loc=p3, scale_diag=[0.01])

# %%
# Example of a sampled galaxy after the convolution with the PSF 
plt.imshow(x_convolve[0,...,0])

# %%
# Plotting the original, predicted and their differences for 32 examples
num_rows, num_cols = 4, 8

plt.figure(figsize=(14.5, 8))

fig, axes = plt.subplots(num_rows, num_cols, figsize=(14.5, 8))

for ax, z_img in zip(axes.flatten(), x_convolve):
    ax.imshow(z_img)
    ax.axis("off")

# Add a title to the figure
fig.suptitle("Galaxies examples", fontsize=12, y=0.99)

# Adjust the layout of the subplots
fig.tight_layout()

cb_ax = fig.add_axes([1.005,.03,.015,.90])
fig.colorbar(ax.imshow(z_img),label="Pixel Value", orientation="vertical", cax=cb_ax) #,ax=axes.ravel().tolist())

wandb.log({'reconstructed_galaxies': wandb.Image(plt)})

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">exp-6</strong> at: <a href='https://wandb.ai/jonnyytorres/NF-results/runs/tqspded4' target="_blank">https://wandb.ai/jonnyytorres/NF-results/runs/tqspded4</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230927_154134-tqspded4/logs</code>

# %%
import galsim

STAMP_SIZE = 128
PIXEL_SCALE = 0.03

# Loads COSMOS sample
cosmos_cat = galsim.COSMOSCatalog()

# Noise model
cosmos_noise = galsim.getCOSMOSNoise()

# %%
# Converting array into float32
x_convolve_ = np.float32(x_convolve)

# %%
plt.figure(figsize=(17.5,4))
for i in range(9):
    im_real = galsim.ImageF(STAMP_SIZE, STAMP_SIZE, scale=PIXEL_SCALE)
    im_sim = galsim.ImageF(np.float32(q_nf[i,...,0]), copy=True)
    im_sim_n = galsim.ImageF(STAMP_SIZE, STAMP_SIZE, scale=PIXEL_SCALE)
    
    # Drawing galaxy from cosmos
    gal = cosmos_cat.makeGalaxy(i, gal_type='real', noise_pad_size=0.8*STAMP_SIZE*PIXEL_SCALE)
    psf = gal.original_psf
    real = galsim.Convolve(psf, gal)
    real.drawImage(im_real, method='no_pixel');
    
    # Drawing galaxy from generative model
    im_sim.addNoise(cosmos_noise)

    my_moments = im_sim.FindAdaptiveMom()

    # print(np.mean([my_moments.observed_shape.g1, my_moments.observed_shape.g2]), my_moments.moments_sigma)
    
    plt.subplot(2,9,i+1)
    plt.imshow(im_real.array, cmap='gray',vmin=-0.01,vmax=0.03)
    plt.axis('off')
    if i==0:
        plt.text(2, 5, "COSMOS", verticalalignment='top', fontsize=14, color="white", weight="bold")
    
    plt.subplot(2,9,i+1+9)
    plt.imshow(im_sim.array, cmap='gray',vmin=-0.01,vmax=0.03)   
    plt.axis('off')
    if i==0:
        plt.text(2, 5, "Flow-VAE\n+PSF+noise", verticalalignment='top', fontsize=14, color="white", weight="bold")

plt.subplots_adjust(wspace=0, hspace=0)
# savefig('Figures/Figure1.pdf',bbox_inches='tight')

# %%
all_moments = {'COSMOS' : 
               {
                   'mean_ellipcity' : [],
                   'determinant_radius' : [],
               },
               'MOCK' : 
               {
                   'mean_ellipcity' : [],
                   'determinant_radius' : [],
               }
              }

def galaxy_moments(galaxy_image):
    my_moments = galaxy_image.FindAdaptiveMom()
    moments = [np.mean([my_moments.observed_shape.g1, my_moments.observed_shape.g2]), my_moments.moments_sigma*PIXEL_SCALE]
    return moments

# %%
@jax.jit
def decode(params, x):
  return dec.apply(params, x)

# %%
num_errors = 0 

for i in range(626):
    # Another batch for the dataset
    batch = next(dset)

    # Taking 32 images
    x = batch['image']

    # Number of images
    num_images = x.shape[0]
    
    # Sampling 32 examples from the NF 
    samps = sampler.apply(params_nf, jax.random.PRNGKey(1), 32)
    
    # Resahping to original bottleneck size
    samps_r = samps.reshape(-1,8,8,1)
     
    # Estimating the original distribution by using the decoder
    q_nf = decode(params_auto, samps_r)

    # Taking the PSF parameters from the batch
    kpsf_real = batch["kpsf_real"]
    kpsf_imag = batch["kpsf_imag"]
    kpsf = kpsf_real + 1j * kpsf_imag
    
    # Convolving the estimated image with the PSF
    x_convolve = jax.vmap(convolve_kpsf)(q_nf[..., 0], kpsf[..., 0])

    # Adding the 'channels' dimension
    x_convolve = tf.expand_dims(x_convolve, axis=-1)

    x_convolve = np.float32(x_convolve)

    for j in range(num_images):
        try:
            # Calculating moments for simulated images
            im_sim = galsim.ImageF((x_convolve[j,...,0]), copy=True)
            im_sim.addNoise(cosmos_noise)
            all_moments['MOCK']['mean_ellipcity'].append(galaxy_moments(im_sim)[0])
            all_moments['MOCK']['determinant_radius'].append(galaxy_moments(im_sim)[1])
            
            # Calculating moments for COSMOS images
            im_real = galsim.ImageF(x[j,...,0], copy=True)
            im_real.addNoise(cosmos_noise)
            all_moments['COSMOS']['mean_ellipcity'].append(galaxy_moments(im_real)[0])
            all_moments['COSMOS']['determinant_radius'].append(galaxy_moments(im_real)[1])
        except:
            num_errors +=1
            print("Something went wrong doing the for cycle, number of errors = {}, cycle = {}".format(num_errors, i*32+j))
# Out:
# /local/home/jt275011/.local/lib/python3.8/site-packages/tensorflow_probability/python/internal/backend/jax/ops.py:285: UserWarning: Explicitly requested dtype int64 requested in astype is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return arr.astype(dtype)
# Working with z of shape (1, 1, 8, 8) = 64 dimensions.
# Something went wrong doing the for cycle, number of errors = 1, cycle = 46
# Something went wrong doing the for cycle, number of errors = 2, cycle = 138
# Something went wrong doing the for cycle, number of errors = 3, cycle = 179
# Something went wrong doing the for cycle, number of errors = 4, cycle = 182
# Something went wrong doing the for cycle, number of errors = 5, cycle = 360
# Something went wrong doing the for cycle, number of errors = 6, cycle = 415
# Something went wrong doing the for cycle, number of errors = 7, cycle = 543
# Something went wrong doing the for cycle, number of errors = 8, cycle = 737
# Something went wrong doing the for cycle, number of errors = 9, cycle = 755
# Something went wrong doing the for cycle, number of errors = 10, cycle = 813
# Something went wrong doing the for cycle, number of errors = 11, cycle = 906
# Something went wrong doing the for cycle, number of errors = 12, cycle = 960
# Something went wrong doing the for cycle, number of errors = 13, cycle = 991
# Something went wrong doing the for cycle, number of errors = 14, cycle = 993
# Something went wrong doing the for cycle, number of errors = 15, cycle = 1069
# Something went wrong doing the for cycle, number of errors = 16, cycle = 1084
# Something went wrong doing the for cycle, number of errors = 17, cycle = 1144
# Something went wrong doing the for cycle, number of errors = 18, cycle = 1398
# Something went wrong doing the for cycle, number of errors = 19, cycle = 1547
# Something went wrong doing the for cycle, number of errors = 20, cycle = 1608
# Something went wrong doing the for cycle, number of errors = 21, cycle = 1661
# Something went wrong doing the for cycle, number of errors = 22, cycle = 1718
# Something went wrong doing the for cycle, number of errors = 23, cycle = 1874
# Something went wrong doing the for cycle, number of errors = 24, cycle = 1984
# Something went wrong doing the for cycle, number of errors = 25, cycle = 1999
# Something went wrong doing the for cycle, number of errors = 26, cycle = 2219
# Something went wrong doing the for cycle, number of errors = 27, cycle = 2279
# Something went wrong doing the for cycle, number of errors = 28, cycle = 2319
# Something went wrong doing the for cycle, number of errors = 29, cycle = 2366
# Something went wrong doing the for cycle, number of errors = 30, cycle = 2453
# Something went wrong doing the for cycle, number of errors = 31, cycle = 2468
# Something went wrong doing the for cycle, number of errors = 32, cycle = 2818
# Something went wrong doing the for cycle, number of errors = 33, cycle = 2889
# Something went wrong doing the for cycle, number of errors = 34, cycle = 2914
# Something went wrong doing the for cycle, number of errors = 35, cycle = 3058
# Something went wrong doing the for cycle, number of errors = 36, cycle = 3134
# Something went wrong doing the for cycle, number of errors = 37, cycle = 3267
# Something went wrong doing the for cycle, number of errors = 38, cycle = 3337
# Something went wrong doing the for cycle, number of errors = 39, cycle = 3485
# Something went wrong doing the for cycle, number of errors = 40, cycle = 3512
# Something went wrong doing the for cycle, number of errors = 41, cycle = 3705
# Something went wrong doing the for cycle, number of errors = 42, cycle = 3765
# Something went wrong doing the for cycle, number of errors = 43, cycle = 3930
# Something went wrong doing the for cycle, number of errors = 44, cycle = 4024
# Something went wrong doing the for cycle, number of errors = 45, cycle = 4031
# Something went wrong doing the for cycle, number of errors = 46, cycle = 4064
# Something went wrong doing the for cycle, number of errors = 47, cycle = 4275
# Something went wrong doing the for cycle, number of errors = 48, cycle = 4316
# Something went wrong doing the for cycle, number of errors = 49, cycle = 4384
# Something went wrong doing the for cycle, number of errors = 50, cycle = 4560
# Something went wrong doing the for cycle, number of errors = 51, cycle = 4599
# Something went wrong doing the for cycle, number of errors = 52, cycle = 4636
# Something went wrong doing the for cycle, number of errors = 53, cycle = 4696
# Something went wrong doing the for cycle, number of errors = 54, cycle = 4735
# Something went wrong doing the for cycle, number of errors = 55, cycle = 4762
# Something went wrong doing the for cycle, number of errors = 56, cycle = 4822
# Something went wrong doing the for cycle, number of errors = 57, cycle = 5052
# Something went wrong doing the for cycle, number of errors = 58, cycle = 5105
# Something went wrong doing the for cycle, number of errors = 59, cycle = 5115
# Something went wrong doing the for cycle, number of errors = 60, cycle = 5332
# Something went wrong doing the for cycle, number of errors = 61, cycle = 5348
# Something went wrong doing the for cycle, number of errors = 62, cycle = 5391
# Something went wrong doing the for cycle, number of errors = 63, cycle = 5529
# Something went wrong doing the for cycle, number of errors = 64, cycle = 5532
# Something went wrong doing the for cycle, number of errors = 65, cycle = 5609
# Something went wrong doing the for cycle, number of errors = 66, cycle = 5679
# Something went wrong doing the for cycle, number of errors = 67, cycle = 5744
# Something went wrong doing the for cycle, number of errors = 68, cycle = 5936
# Something went wrong doing the for cycle, number of errors = 69, cycle = 6100
# Something went wrong doing the for cycle, number of errors = 70, cycle = 6199
# Something went wrong doing the for cycle, number of errors = 71, cycle = 6218
# Something went wrong doing the for cycle, number of errors = 72, cycle = 6252
# Something went wrong doing the for cycle, number of errors = 73, cycle = 6302
# Something went wrong doing the for cycle, number of errors = 74, cycle = 6376
# Something went wrong doing the for cycle, number of errors = 75, cycle = 6482
# Something went wrong doing the for cycle, number of errors = 76, cycle = 6520
# Something went wrong doing the for cycle, number of errors = 77, cycle = 6647
# Something went wrong doing the for cycle, number of errors = 78, cycle = 6681
# Something went wrong doing the for cycle, number of errors = 79, cycle = 6786
# Something went wrong doing the for cycle, number of errors = 80, cycle = 6877
# Something went wrong doing the for cycle, number of errors = 81, cycle = 6903
# Something went wrong doing the for cycle, number of errors = 82, cycle = 6926
# Something went wrong doing the for cycle, number of errors = 83, cycle = 7111
# Something went wrong doing the for cycle, number of errors = 84, cycle = 7227
# Something went wrong doing the for cycle, number of errors = 85, cycle = 7260
# Something went wrong doing the for cycle, number of errors = 86, cycle = 7281
# Something went wrong doing the for cycle, number of errors = 87, cycle = 7339
# Something went wrong doing the for cycle, number of errors = 88, cycle = 7375
# Something went wrong doing the for cycle, number of errors = 89, cycle = 7454
# Something went wrong doing the for cycle, number of errors = 90, cycle = 7477
# Something went wrong doing the for cycle, number of errors = 91, cycle = 7502
# Something went wrong doing the for cycle, number of errors = 92, cycle = 7564
# Something went wrong doing the for cycle, number of errors = 93, cycle = 7574
# Something went wrong doing the for cycle, number of errors = 94, cycle = 7708
# Something went wrong doing the for cycle, number of errors = 95, cycle = 7792
# Something went wrong doing the for cycle, number of errors = 96, cycle = 7916
# Something went wrong doing the for cycle, number of errors = 97, cycle = 7952
# Something went wrong doing the for cycle, number of errors = 98, cycle = 8198
# Something went wrong doing the for cycle, number of errors = 99, cycle = 8385
# Something went wrong doing the for cycle, number of errors = 100, cycle = 8453
# Something went wrong doing the for cycle, number of errors = 101, cycle = 8560
# Something went wrong doing the for cycle, number of errors = 102, cycle = 8656
# Something went wrong doing the for cycle, number of errors = 103, cycle = 8760
# Something went wrong doing the for cycle, number of errors = 104, cycle = 8792
# Something went wrong doing the for cycle, number of errors = 105, cycle = 8992
# Something went wrong doing the for cycle, number of errors = 106, cycle = 9235
# Something went wrong doing the for cycle, number of errors = 107, cycle = 9313
# Something went wrong doing the for cycle, number of errors = 108, cycle = 9356
# Something went wrong doing the for cycle, number of errors = 109, cycle = 9398
# Something went wrong doing the for cycle, number of errors = 110, cycle = 9504
# Something went wrong doing the for cycle, number of errors = 111, cycle = 9599
# Something went wrong doing the for cycle, number of errors = 112, cycle = 9607
# Something went wrong doing the for cycle, number of errors = 113, cycle = 9617
# Something went wrong doing the for cycle, number of errors = 114, cycle = 9699
# Something went wrong doing the for cycle, number of errors = 115, cycle = 9750
# Something went wrong doing the for cycle, number of errors = 116, cycle = 9964
# Something went wrong doing the for cycle, number of errors = 117, cycle = 10037
# Something went wrong doing the for cycle, number of errors = 118, cycle = 10104
# Something went wrong doing the for cycle, number of errors = 119, cycle = 10238
# Something went wrong doing the for cycle, number of errors = 120, cycle = 10315
# Something went wrong doing the for cycle, number of errors = 121, cycle = 10443
# Something went wrong doing the for cycle, number of errors = 122, cycle = 10481
# Something went wrong doing the for cycle, number of errors = 123, cycle = 10580
# Something went wrong doing the for cycle, number of errors = 124, cycle = 10598
# Something went wrong doing the for cycle, number of errors = 125, cycle = 10612
# Something went wrong doing the for cycle, number of errors = 126, cycle = 10632
# Something went wrong doing the for cycle, number of errors = 127, cycle = 10649
# Something went wrong doing the for cycle, number of errors = 128, cycle = 10676
# Something went wrong doing the for cycle, number of errors = 129, cycle = 10783
# Something went wrong doing the for cycle, number of errors = 130, cycle = 10963
# Something went wrong doing the for cycle, number of errors = 131, cycle = 10966
# Something went wrong doing the for cycle, number of errors = 132, cycle = 11020
# Something went wrong doing the for cycle, number of errors = 133, cycle = 11049
# Something went wrong doing the for cycle, number of errors = 134, cycle = 11104
# Something went wrong doing the for cycle, number of errors = 135, cycle = 11123
# Something went wrong doing the for cycle, number of errors = 136, cycle = 11168
# Something went wrong doing the for cycle, number of errors = 137, cycle = 11243
# Something went wrong doing the for cycle, number of errors = 138, cycle = 11256
# Something went wrong doing the for cycle, number of errors = 139, cycle = 11262
# Something went wrong doing the for cycle, number of errors = 140, cycle = 11390
# Something went wrong doing the for cycle, number of errors = 141, cycle = 11510
# Something went wrong doing the for cycle, number of errors = 142, cycle = 11512
# Something went wrong doing the for cycle, number of errors = 143, cycle = 11731
# Something went wrong doing the for cycle, number of errors = 144, cycle = 11766
# Something went wrong doing the for cycle, number of errors = 145, cycle = 11802
# Something went wrong doing the for cycle, number of errors = 146, cycle = 11862
# Something went wrong doing the for cycle, number of errors = 147, cycle = 11945
# Something went wrong doing the for cycle, number of errors = 148, cycle = 11964
# Something went wrong doing the for cycle, number of errors = 149, cycle = 12069
# Something went wrong doing the for cycle, number of errors = 150, cycle = 12162
# Something went wrong doing the for cycle, number of errors = 151, cycle = 12282
# Something went wrong doing the for cycle, number of errors = 152, cycle = 12379
# Something went wrong doing the for cycle, number of errors = 153, cycle = 12438
# Something went wrong doing the for cycle, number of errors = 154, cycle = 12558
# Something went wrong doing the for cycle, number of errors = 155, cycle = 12559
# Something went wrong doing the for cycle, number of errors = 156, cycle = 12638
# Something went wrong doing the for cycle, number of errors = 157, cycle = 12641
# Something went wrong doing the for cycle, number of errors = 158, cycle = 12720
# Something went wrong doing the for cycle, number of errors = 159, cycle = 12745
# Something went wrong doing the for cycle, number of errors = 160, cycle = 12812
# Something went wrong doing the for cycle, number of errors = 161, cycle = 12825
# Something went wrong doing the for cycle, number of errors = 162, cycle = 12926
# Something went wrong doing the for cycle, number of errors = 163, cycle = 12972
# Something went wrong doing the for cycle, number of errors = 164, cycle = 13084
# Something went wrong doing the for cycle, number of errors = 165, cycle = 13097
# Something went wrong doing the for cycle, number of errors = 166, cycle = 13248
# Something went wrong doing the for cycle, number of errors = 167, cycle = 13297
# Something went wrong doing the for cycle, number of errors = 168, cycle = 13329
# Something went wrong doing the for cycle, number of errors = 169, cycle = 13394
# Something went wrong doing the for cycle, number of errors = 170, cycle = 13417
# Something went wrong doing the for cycle, number of errors = 171, cycle = 13425
# Something went wrong doing the for cycle, number of errors = 172, cycle = 13508
# Something went wrong doing the for cycle, number of errors = 173, cycle = 13549
# Something went wrong doing the for cycle, number of errors = 174, cycle = 13704
# Something went wrong doing the for cycle, number of errors = 175, cycle = 13767
# Something went wrong doing the for cycle, number of errors = 176, cycle = 13865
# Something went wrong doing the for cycle, number of errors = 177, cycle = 13881
# Something went wrong doing the for cycle, number of errors = 178, cycle = 13899
# Something went wrong doing the for cycle, number of errors = 179, cycle = 14047
# Something went wrong doing the for cycle, number of errors = 180, cycle = 14203
# Something went wrong doing the for cycle, number of errors = 181, cycle = 14219
# Something went wrong doing the for cycle, number of errors = 182, cycle = 14405
# Something went wrong doing the for cycle, number of errors = 183, cycle = 14414
# Something went wrong doing the for cycle, number of errors = 184, cycle = 14460
# Something went wrong doing the for cycle, number of errors = 185, cycle = 14511
# Something went wrong doing the for cycle, number of errors = 186, cycle = 14513
# Something went wrong doing the for cycle, number of errors = 187, cycle = 14629
# Something went wrong doing the for cycle, number of errors = 188, cycle = 14742
# Something went wrong doing the for cycle, number of errors = 189, cycle = 14780
# Something went wrong doing the for cycle, number of errors = 190, cycle = 14894
# Something went wrong doing the for cycle, number of errors = 191, cycle = 14958
# Something went wrong doing the for cycle, number of errors = 192, cycle = 15109
# Something went wrong doing the for cycle, number of errors = 193, cycle = 15221
# Something went wrong doing the for cycle, number of errors = 194, cycle = 15280
# Something went wrong doing the for cycle, number of errors = 195, cycle = 15310
# Something went wrong doing the for cycle, number of errors = 196, cycle = 15516
# Something went wrong doing the for cycle, number of errors = 197, cycle = 15532
# Something went wrong doing the for cycle, number of errors = 198, cycle = 15609
# Something went wrong doing the for cycle, number of errors = 199, cycle = 15632
# Something went wrong doing the for cycle, number of errors = 200, cycle = 15685
# Something went wrong doing the for cycle, number of errors = 201, cycle = 15789
# Something went wrong doing the for cycle, number of errors = 202, cycle = 16071
# Something went wrong doing the for cycle, number of errors = 203, cycle = 16085
# Something went wrong doing the for cycle, number of errors = 204, cycle = 16116
# Something went wrong doing the for cycle, number of errors = 205, cycle = 16124
# Something went wrong doing the for cycle, number of errors = 206, cycle = 16235
# Something went wrong doing the for cycle, number of errors = 207, cycle = 16317
# Something went wrong doing the for cycle, number of errors = 208, cycle = 16406
# Something went wrong doing the for cycle, number of errors = 209, cycle = 16449
# Something went wrong doing the for cycle, number of errors = 210, cycle = 16460
# Something went wrong doing the for cycle, number of errors = 211, cycle = 16475
# Something went wrong doing the for cycle, number of errors = 212, cycle = 16528
# Something went wrong doing the for cycle, number of errors = 213, cycle = 16555
# Something went wrong doing the for cycle, number of errors = 214, cycle = 16560
# Something went wrong doing the for cycle, number of errors = 215, cycle = 16604
# Something went wrong doing the for cycle, number of errors = 216, cycle = 16610
# Something went wrong doing the for cycle, number of errors = 217, cycle = 16669
# Something went wrong doing the for cycle, number of errors = 218, cycle = 16803
# Something went wrong doing the for cycle, number of errors = 219, cycle = 16908
# Something went wrong doing the for cycle, number of errors = 220, cycle = 17065
# Something went wrong doing the for cycle, number of errors = 221, cycle = 17112
# Something went wrong doing the for cycle, number of errors = 222, cycle = 17172
# Something went wrong doing the for cycle, number of errors = 223, cycle = 17229
# Something went wrong doing the for cycle, number of errors = 224, cycle = 17369
# Something went wrong doing the for cycle, number of errors = 225, cycle = 17428
# Something went wrong doing the for cycle, number of errors = 226, cycle = 17450
# Something went wrong doing the for cycle, number of errors = 227, cycle = 17550
# Something went wrong doing the for cycle, number of errors = 228, cycle = 17579
# Something went wrong doing the for cycle, number of errors = 229, cycle = 17685
# Something went wrong doing the for cycle, number of errors = 230, cycle = 17803
# Something went wrong doing the for cycle, number of errors = 231, cycle = 18023
# Something went wrong doing the for cycle, number of errors = 232, cycle = 18170
# Something went wrong doing the for cycle, number of errors = 233, cycle = 18300
# Something went wrong doing the for cycle, number of errors = 234, cycle = 18315
# Something went wrong doing the for cycle, number of errors = 235, cycle = 18466
# Something went wrong doing the for cycle, number of errors = 236, cycle = 18615
# Something went wrong doing the for cycle, number of errors = 237, cycle = 18682
# Something went wrong doing the for cycle, number of errors = 238, cycle = 18710
# Something went wrong doing the for cycle, number of errors = 239, cycle = 18722
# Something went wrong doing the for cycle, number of errors = 240, cycle = 18845
# Something went wrong doing the for cycle, number of errors = 241, cycle = 18904
# Something went wrong doing the for cycle, number of errors = 242, cycle = 18913
# Something went wrong doing the for cycle, number of errors = 243, cycle = 18916
# Something went wrong doing the for cycle, number of errors = 244, cycle = 19218
# Something went wrong doing the for cycle, number of errors = 245, cycle = 19275
# Something went wrong doing the for cycle, number of errors = 246, cycle = 19464
# Something went wrong doing the for cycle, number of errors = 247, cycle = 19519
# Something went wrong doing the for cycle, number of errors = 248, cycle = 19643
# Something went wrong doing the for cycle, number of errors = 249, cycle = 19724
# Something went wrong doing the for cycle, number of errors = 250, cycle = 19781

# %%
plt.hist(all_moments['COSMOS']['mean_ellipcity']);

# %%
len(all_moments['COSMOS']['mean_ellipcity'])
# Out:
# 19782

# %%
import seaborn as sns

sns.set()
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2})

creal = plt.cm.viridis(0.1)
cmock = plt.cm.viridis(0.35)

plt.figure(figsize=(10,4))
plt.subplot(121)

sns.distplot(all_moments['COSMOS']['mean_ellipcity'], label='COSMOS', hist=False, color=creal);
# plt.axvline(np.mean(all_moments['COSMOS']['mean_ellipcity']), color=creal)
sns.distplot(all_moments['MOCK']['mean_ellipcity'], label='mock', hist=False, color=cmock);
# plt.axvline(np.mean(all_moments['MOCK']['mean_ellipcity']), color=cmock)
plt.xlim(0,0.8)
plt.legend()
plt.xlabel('Ellipticity $g$')
# print("Mean real ellipticity: %0.4f +/- %0.4f"%(np.mean(all_moments['COSMOS']['mean_ellipcity'])),
#                                                 sem(all_moments['COSMOS']['mean_ellipcity']))
# print("Mean mock ellipticity: %0.4f +/- %0.4f"%(np.mean(all_moments['MOCK']['mean_ellipcity'])),
#                                                 sem(all_moments['MOCK']['mean_ellipcity']))

plt.subplot(122)
sns.distplot(all_moments['COSMOS']['determinant_radius'], label='COSMOS', hist=False, color=creal);
# plt.axvline(np.mean(all_moments['COSMOS']['determinant_radius']*res), color=creal)
sns.distplot(all_moments['MOCK']['determinant_radius'], label='mock', hist=False, color=cmock);
# plt.axvline(np.mean(all_moments['MOCK']['determinant_radius']*res), color=cmock)
plt.legend()
plt.xlabel('Determinant radius [arcsec]')
plt.xlim(0.05,0.6);
# print("Mean real size: %0.4f +/-%0.4f"%(np.mean(all_moments['COSMOS']['determinant_radius']*res),
#                                                 sem(all_moments['COSMOS']['determinant_radius']*res)))
# print("Mean mock size: %0.4f +/-%0.4f"%(np.mean(all_moments['MOCK']['determinant_radius']*res),
#                                                 sem(all_moments['MOCK']['determinant_radius']*res)))
# Out:
# /tmp/ipykernel_3154919/2388531387.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(all_moments['COSMOS']['mean_ellipcity'], label='COSMOS', hist=False, color=creal);
# /tmp/ipykernel_3154919/2388531387.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(all_moments['MOCK']['mean_ellipcity'], label='mock', hist=False, color=cmock);
# /tmp/ipykernel_3154919/2388531387.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(all_moments['COSMOS']['determinant_radius'], label='COSMOS', hist=False, color=creal);
# /tmp/ipykernel_3154919/2388531387.py:28: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(all_moments['MOCK']['determinant_radius'], label='mock', hist=False, color=cmock);
